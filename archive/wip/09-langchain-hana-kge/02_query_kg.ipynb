# %% [markdown]
# ## Connect to your SAP HANA database

# %%
# %run "../01-check_setup.ipynb"
# Out:
# SAP HANA Client for Python: 2.26.25111700
# Using the dot-env file /home/user/projects/hana-ai-ve-kg-codejam/.env
# Connected to SAP HANA db version 4.00.000.00.1774948521 (fa/CE2026.2)
# at c5889dd5-e0f6-4930-8408-94d53ca61dbf.hna0.prod-us10.hanacloud.ondemand.com:443 as DBADMIN_VR
# Current time on the SAP HANA server: 2026-04-08 12:17:15.215000

# %% [markdown]
# Load SQLAlchemy magic extension: https://pypi.org/project/ipython-sql/#description

# %%
# %load_ext sql

# Use `%config SqlMagic` for configuration changes, if needed

# %% [markdown]
# Connect using SQLAlchemy Dialect for SAP HANA: https://pypi.org/project/sqlalchemy-hana/#description

# %%
# %sql hana://{os.environ["HANADB_USR"]}:{os.environ["HANADB_PWD"]}@{os.environ["HANADB_URL"]}:{os.environ["HANADB_PRT"]}

# %%
# %%sql
#
# SELECT Current_Time FROM DUMMY;
# Out:
#  * hana://DBADMIN_VR:***@c5889dd5-e0f6-4930-8408-94d53ca61dbf.hna0.prod-us10.hanacloud.ondemand.com:443
# Done.
# [(datetime.time(12, 18, 8),)]

# %% [markdown]
# ## Try examples from the doc's tutorial:
#
# https://help.sap.com/docs/hana-cloud-database/sap-hana-cloud-sap-hana-database-sparql-reference-guide/sparql-select-queries-using-sparql-table?locale=en-US&version=LATEST

# %%
# %%sql
#
# SELECT * FROM SPARQL_TABLE('
# 	SELECT *
# 	FROM <kgdocu_movies>
# 	WHERE {
# 		?s ?p ?o .
# 	}
# 	LIMIT 5
# ');
# Out:
#  * hana://DBADMIN_VR:***@c5889dd5-e0f6-4930-8408-94d53ca61dbf.hna0.prod-us10.hanacloud.ondemand.com:443
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File ~/projects/hana-ai-ve-kg-codejam/env/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/projects/hana-ai-ve-kg-codejam/env/lib/python3.13/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ...

# %%
# %%sql
#
# SELECT * FROM SPARQL_TABLE('
# PREFIX demo: <http://kg.demo.sap.com/>
# 	SELECT ?movie ?p ?o
# 	FROM <kgdocu_movies>
# 	WHERE {
# 	  ?movie a demo:Film ;
# 	  	demo:title "The Matrix" ;
# 	  	?p ?o .
# 	}
# 	ORDER BY DESC(?p) LIMIT 10
# ');
